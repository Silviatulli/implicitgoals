# %%
import pandas as pd
df = pd.read_csv("experiment_results_2/enhanced_pybullet_comparison.csv")
df
# Out:
#    Environment  Grid Size  Number of Human Models  Obstacle Percentage  \
# 0         Grid        4.0                       3                 0.10
# 1         Grid        4.0                       3                 0.15
# 2       Puddle        4.0                       3                 0.10
# 3       Puddle        4.0                       3                 0.15
# 4         Rock        4.0                       3                 0.10
# 5         Rock        4.0                       3                 0.15
# 6   Overcooked        NaN                       3                  NaN
# 7         Grid        4.0                       4                 0.10
# 8         Grid        4.0                       4                 0.15
# 9       Puddle        4.0                       4                 0.10
# 10      Puddle        4.0                       4                 0.15
# 11        Rock        4.0                       4                 0.10
# ...
